# %% [markdown]
# # Введение в Python
#
# *Алла Тамбовцева*
#
# ## Домашнее задание

# %% [markdown]
# В задачах ниже понадобится запрашивать какую-то информацию у пользователя с клавиатуры. Для этого нужно использовать функцию `input()`, примеры использования которой были приведены в видео-уроках.
#
# Во всех задачах под *входными данными* подразумевается то, что ввёл пользователь (с клавиатуры или просто сохранил в переменную),  под *выходными данными* – результат исполнения кода. *Программа* здесь – строки кода, необходимые для выполнения задачи и выдачи результатов на экран.

# %% [markdown]
# ### Задача 1
#
# Вычислите в Python:
#
# $9^2 + 6^4$;
#
# $\log(54)$ (натуральный логарифм);
#
# $\sqrt{8} - \sqrt{12}$;
#
# $\sin(45) + \cos(45)$.

# %%
from math import log, sqrt, sin, cos

#несовсем понял нужно именно числа из примера посчитать или пользовательский инпут поэтому сделал двумя способами

def change(num, bo):
    if num==1: # сделал как мне показалось удобное переключение по программе, с возможностью выбора заданий
        if bo == 1: # поскольку непонял нужно только ввод пользователя (input) учитывать или данные из задачи сделал возможность выбора 
                    # показать ответ только пользовательского ввода или данных из задачи
            print((9**2)+(6**4))  # цифры из задачи
        else:
            print((int(input('первое число '))**int(input('степень первого числа ')))+(int(input('второе число '))**int(input('степень второго числа ')))) # ввод пользователя
    elif num==2:
        if bo == 1:
            print(log(54))
        else:
            print(log(int(input('Введите число: '))))
    elif num==3:
        if bo==1:
            print(sqrt(8)-sqrt(12))
        else:
            print(sqrt(int(input('Введите число ')))-sqrt(int(input('Введите второе число '))))
    elif num==4:
        if bo==1:
            print(sin(45)+cos(45))
        else:
            print(sin(int(input('Введите число')))+sin(int(input('Введите второе число'))))
    else:
        print('Вы ввели несуществующий номер задачи')
        change(int(input('Выберите номер задачи: ')), int(input('Считаем цифры из задачи или пользовательский ввод? значение 0-пользовательский ввод, значение 1-цифры из задачи : ')))
        
change(int(input('Выберите номер задачи: ')), int(input('Считаем цифры из задачи или пользовательский ввод? значение 0-пользовательский ввод, значение 1-цифры из задачи : ')))
# Out:
# Выберите номер задачи:  1
# Считаем цифры из задачи или пользовательский ввод? значение 0-пользовательский ввод, значение 1-цифры из задачи :  1
# 1377

# %%
# 1 задача
print((int(input('первое число '))**int(input('степень первого числа ')))+(int(input('второе число '))**int(input('степень второго числа '))))
# Out:
# первое число  5
# степень первого числа  6
# второе число  4
# степень второго числа  2
# 15641

# %%
# 2 задача
print(log(int(input('Введите число: '))))
# Out:
# Введите число:  2
# 0.6931471805599453

# %%
# 3 задача
print(sqrt(int(input('Введите число ')))-sqrt(int(input('Введите второе число '))))
# Out:
# Введите число  4
# Введите второе число  2
# 0.5857864376269049

# %%
# 4 задача
print(sin(int(input('Введите число')))+sin(int(input('Введите второе число'))))
# Out:
# Введите число 5
# Введите второе число 4
# -1.7157267699710665

# %% [markdown]
# ### Задача 2
#
# Напишите программу, которая запрашивает у пользователя размер обуви, а выводит на экран размер скальных туфель (туфли для скалолазания), учитывая, что обычно размер скальных туфель на 2 размера меньше обычного.
#
# **Пример работы программы:**
#
# *Входные данные*
#
#     38
#
# *Выходные данные*
#
#     36

# %%
print(int(input('Введите размер обуви: '))-2)
# Out:
# Введите размер обуви:  56
# 54

# %% [markdown]
# ### Задача 3
#
# Тест по английскому языку состоит из трёх частей. Ученик последовательно вводит с клавиатуры набранные баллы за каждую часть – три целых числа. Каждое число вводится на отдельной строке, то есть `input()` запрашивается три раза. Напишите программу, которая считает итоговый балл за тест – сумму баллов за три части.
#
# **Пример работы программы:**
#
# *Входные данные*
#
#     5
#     4
#     6
#
# *Выходные данные*
#
#     15

# %%
print(int(input('Введите первую оценку: '))+int(input('Введите вторую оценку: '))+int(input('Введите третью оценку: ')))

# %% [markdown]
# ### Задача 4
#
# В переменной `salary` хранится значение заработной платы человека в рублях (можете сами присвоить `salary` какое-нибудь значение).
#
# Напишите программу, которая выражает заработную плату человека в *тысячах рублей* и
#
#
# a) сохраняет результат в переменную `salary_th` и выводит результат на экран;
#
# b) выводит на экран сообщение (с подставленным вместо `___` значением):
#
#     Ваша заработная плата __ тысяч рублей.
#
# **Пример работы программы (пункт a):**
#
#
# *Входные данные*
#
#     salary = 35000
#
# *Выходные данные*
#
#     35
#
# **Пример работы программы (пункт b):**
#
#
# *Входные данные*
#
#     salary = 35000
#
# *Выходные данные*
#
#     Ваша заработная плата 35 тысяч рублей.

# %%
#а зачем тут переменные то? вроде все в одну строчку без проблемм делается
print('Ваша заработная плата '+str(input('Введите вашу зарплату: '))[:-3]+' тысяч рублей')

# %% [markdown]
# ### Задача 5
#
# Напишите программу, которая запрашивает у пользователя сумму (в рублях), которую он хочет перевести своему другу на карту другого банка, и возвращает сумму списания (в рублях) с учётом комиссии банка 5%.
#
# *Примечание:* считайте, что сумма перевода – целое число.
#
# **Пример работы программы:**
#
# *Входные данные*
#
#     1000
#
# *Выходные данные*
#
#     1050.0

# %%
print('Сумма с учетом комиссии в 5% состовляет: '+str(int(input('Введите сумму: '))*1.05))

# %% [markdown]
# ### Задача 6
#
# Питон выполз на улицу погулять и решил поиграть: просил прохожих назвать какую-нибудь цифру (т.е. ввести её с клавиатуры) и приписывал эту цифру к цифре, которую назвал предыдущий прохожий. Напишите код, который позволит определить, какое число получится после опроса четырёх прохожих, если известно, что первый прохожий назвал цифру 5. Задача не подразумевает использование циклов; запускать код несколько раз / копировать строки кода или ячейки можно. Обратите внимание: в результате должно получиться *целое число*, не строка.
#
# **Пример-пояснение:** первый назвал цифру 5, второй ‒ цифру 6, третий ‒ 3. Получили число 563.
#
# **Пример работы программы:**
#
# *Входные данные*
#
#     5
#     6
#     3
#     0
#
# *Выходные данные*
#
#     5630
#
# **Подсказка:** для склеивания строк (такая операция называется *конкатенацией*) в Python используется `+`:

# %%
# здесь я использовал рекурсию чтобы у пользователя была возможность сколько ему необходимо цифр складывать.

def inp(cifra, sum_cifr):
    sum_cifr=sum_cifr+cifra #какждую итерацию рекурсии добавляем новую цифру к текущим
    if int(input('Продолжаем воодить цифры 0, хватит 1: '))==False: # проверяем что решил пользователь вводить еще одну цифру или нет
        inp(input('Привет прохожий, скажи любую цифру: '),sum_cifr) # если решил вводить то возвращаемся в начало функции
    else:
        print('Итоговая цифра: '+sum_cifr) # если решил не воодить то возвращаем ему сложенные числа
        
inp(input('Привет прохожий, скажи любую цифру: '),'')
# Out:
# Привет прохожий, скажи любую цифру:  3
# Продолжаем воодить цифры 0, хватит 1:  0
# Привет прохожий, скажи любую цифру:  1
# Продолжаем воодить цифры 0, хватит 1:  0
# Привет прохожий, скажи любую цифру:  7
# Продолжаем воодить цифры 0, хватит 1:  0
# Привет прохожий, скажи любую цифру:  4
# Продолжаем воодить цифры 0, хватит 1:  1
# Итоговая цифра: 3174

# %%
# так и непонял в чем суть и почему нельзя регулируемое количество вводов сделать)) по этому вроде так будет правильно?
print(input('Введите первое число: ')+input('Введите второе число: ')+input('Введите третье число: '))
# Out:
# Введите первое число:  5
# Введите второе число:  6
# Введите третье число:  3
# 563

# %% [markdown]
# ### Задача 7* (дополнительная)
#
# Дано целое число `n`. Выведите следующее за ним чётное число. При решении этой задачи *нельзя* использовать условный оператор `if` и циклы.
#
# **Подсказка.** В Python существует оператор целочисленного деления `//` (обсуждалсся в видео-уроках) и взятия остатка при делении `%`. Например, результат выполнения операции `15 % 7` равен 1:

# %%
15 % 7 # 15 : 7 = 2 и 1 в остатке

# %% [markdown]
# **Примеры работы программы**
#
# *Входные данные*
#
#     7
#
# *Выходные данные*
#
#     8
#
# *Входные данные*
#
#     8
#
# *Выходные данные*
#
#     10

# %%
a = int(input())
a+2-(a%2)
# Out:
# 28
# 30
